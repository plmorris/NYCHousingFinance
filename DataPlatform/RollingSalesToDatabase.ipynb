# %%
import requests
import os.path
import pyspark.sql.functions
from pyspark.sql.functions import concat, col, lit, count, when, isnan
from pyspark.sql.types import StringType,DecimalType
import matplotlib.pyplot as plt
from pyspark.sql.functions import input_file_name, substring
import pyspark.sql.functions

from confluent_kafka import Consumer
from time import sleep
import uuid
from confluent_kafka import Producer, Consumer, KafkaError, KafkaException
import json
from confluent_kafka.admin import AdminClient, NewTopic

import json

# %%
storageAccount = "gen10datafund2207"
storageContainer = "finance-capstone-group6-consumer"
clientSecret = "Cty8Q~AvEO_qC-MjvPvosYauiNsffOHKnMpj7cmd"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/gp6-out"


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

dbutils.fs.mount(
source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
mount_point = mount_point,
extra_configs = configs)
# Out:
# Out[267]: True

# %%
display(dbutils.fs.ls("/mnt/gp6-out"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/gp6-out/RollingSales.csv/</td><td>RollingSales.csv/</td><td>0</td><td>1663896789000</td></tr></tbody></table></div>

# %%
df = spark.read.format("csv").load("/mnt/gp6-out/RollingSales.csv", header=True, inferSchema='True')
df_stream.display()
# pd_df = df_stream.toPandas()
# pd_df.head()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# display(dbutils.fs.ls("/mnt/gp6/rollingsales/NYC_Rolling_Sales_clean"))

# %%
# df = spark.read.format("csv").load("/mnt/gp6/rollingsales/NYC_Rolling_Sales_clean/nyrollingproperty.csv", header=True, inferSchema='True')

# display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_clean = df.withColumn("SALE DATE",col("SALE DATE").cast(StringType()))

# %%
df_clean = df_clean.drop('_c0')

# %%
display(df_clean)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#df_zip = df_clean.select(df_clean['ZIP CODE']) #into sql columns 'zipcode' in 'ZipCode' table

# %%
neighborhood = df_clean.select('BOROUGH','NEIGHBORHOOD').distinct()
df_with_increasing_id = neighborhood.withColumn("monotonically_increasing_id", pyspark.sql.functions.monotonically_increasing_id())

# %%
df_clean_test = df_clean
df_clean_with_id = df_with_increasing_id.join(df_clean_test, on=['NEIGHBORHOOD','BOROUGH'], how='inner')
df_clean_with_id.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_clean.select('BOROUGH').distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>BOROUGH</th></tr></thead><tbody><tr><td>1</td></tr><tr><td>3</td></tr><tr><td>5</td></tr><tr><td>4</td></tr><tr><td>2</td></tr></tbody></table></div>

# %%
#Below outlines which columns from the dataframe goes into which sql table and columns
# df_borough = df_clean_with_id.select(df_clean_with_id['BOROUGH']).distinct() #into sql columns 'borough' in 'Borough' table
df_neighborhood = df_clean_with_id.select('BOROUGH','NEIGHBORHOOD','monotonically_increasing_id').distinct() # into sql column 'neighborhood'

# %%
df_neighborhood.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_RollingSalesTable = df_clean_with_id.drop('BOROUGH', 'NEIGHBORHOOD') 
#^ into sql columns 'buildingCat', 'block', 'lot', 'address', 'resUnits', 'comUnits', 'totUnits', 'landSqrFt', 'grossSqrFt', 'yearBuilt', 'taxClass', 'buildCLass', 'salePrice', 'saleDate' in 'RollingSales' table

# %%
df_RollingSalesTable = df_RollingSalesTable.withColumnRenamed('BUILDING CLASS CATEGORY','buildingCat').withColumnRenamed('BLOCK', 'block')\
    .withColumnRenamed('LOT', 'lot').withColumnRenamed('ADDRESS','address').withColumnRenamed('RESIDENTIAL UNITS', 'resUnits').withColumnRenamed('COMMERCIAL UNITS','comUnits').withColumnRenamed('TOTAL UNITS', 'totUnits').withColumnRenamed('LAND SQUARE FEET', 'landSqrFt').withColumnRenamed('GROSS SQUARE FEET', 'GrossSqrFt').withColumnRenamed('YEAR BUILT', 'yearBuilt').withColumnRenamed('TAX CLASS AT TIME OF SALE', 'taxClass').withColumnRenamed('BUILDING CLASS AT TIME OF SALE', 'buildClass').withColumnRenamed('SALE PRICE','salePrice').withColumnRenamed('SALE DATE', 'saleDate').withColumnRenamed('ZIP CODE', 'zipcode').withColumnRenamed('monotonically_increasing_id','neighborhoodID')

# %%
# df_borough = df_borough.withColumnRenamed('BOROUGH', 'borough')

# %%
df_neighborhood = df_neighborhood.withColumnRenamed('NEIGHBORHOOD','neighborhood').withColumnRenamed('BOROUGH', 'boroughID').withColumnRenamed('monotonically_increasing_id', 'neighborhoodID')

# %%
df_neighborhood.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# df_borough = df_borough.orderBy('borough',ascending=True)
# df_borough.display()

# %%
# # create df for borough
# columns = ["boroughID", "boroughName"]
# data = [(1, "Manhattan"), (2, "Bronx"), (3, "Brooklyn"), (4, "Queens"), (5, "Staten Island")]
# rdd = spark.sparkContext.parallelize(data)
# df_boro = rdd.toDF(columns)
# df_boro.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>boroughID</th><th>boroughName</th></tr></thead><tbody><tr><td>1</td><td>Manhattan</td></tr><tr><td>2</td><td>Bronx</td></tr><tr><td>3</td><td>Brooklyn</td></tr><tr><td>4</td><td>Queens</td></tr><tr><td>5</td><td>Staten Island</td></tr></tbody></table></div>

# %%
database = "group-6-finance"
table1 = "dbo.RollingSales"
table2 = "dbo.Borough"
table3 = "dbo.Neighborhood"
user = "ericks"
password  = "MYP4SSW0RD!"
server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"

# df_boro.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
#     .mode("overwrite") \
#     .option("dbtable", table2) \
#     .option("user", user) \
#     .option("password", password) \
#     .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
#     .save()


df_RollingSalesTable.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table1) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()

df_neighborhood.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
    .mode("overwrite") \
    .option("dbtable", table3) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
    .save()

# %%
# export the dataframe into a SQL database 
# use mode "append" to add to table or "overwrite" to write over table
# dataframe column names and datatypes must match table in database
# database = "group-6-finance"
# table = "dbo.RawRollingSales"
# user = "ericks"
# password  = "MYP4SSW0RD!"
# server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"

# df_clean.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
#     .mode("append") \
#     .option("dbtable", table) \
#     .option("user", user) \
#     .option("password", password) \
#     .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
#     .save()

# %%
# # export the dataframe into a SQL database test
# # 
# database = "group-6-finance"
# table = "dbo.BoroughNeighborhood"
# user = "ericks"
# password  = "MYP4SSW0RD!"
# server = "gen10-data-fundamentals-22-07-sql-server.database.windows.net"

# borough_df.write.format('jdbc').option("url", f"jdbc:sqlserver://{server}:1433;databaseName={database};") \
#     .mode("append") \
#     .option("dbtable", table) \
#     .option("user", user) \
#     .option("password", password) \
#     .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver") \
#     .save()
